# %% [markdown]
# # Load the data from a pickle/HDF5 file

# %%
# %matplotlib inline
import pandas as pd

# %%
pc=pd.read_pickle('data/paths.pkl.xz')

# %%
pc
# Out:
#          frame    x    y  obj      size  seq  \
# 0            0   14  329    0       362    0
# 1            0    4  291    1       362    0
# 2            0  629    7    2       362    0
# 3            0  253    4    3       362    0
# 4            0  185    4    4       362    0
# 5         1700    5  102    5       362    0
# 6         1701    6  102    5       362    1
# 7         1702    6  102    5       362    2
# 8         1703    7  102    5       362    3
# 9         1704    9  102    5       362    4
# 10        1705   11  102    5       362    5
# 11        1739   11  102    5       362    5
# 12        1739   76  100    6       362    0
# 13        1740   11  102    5       362    5
# 14        1740   80  100    6       362    1
# 15        1747   11  102    5       362    5
# 16        1747   94  100    6       362    2
# 17        1749   11  102    5       362    5
# 18        1749   94  100    6       362    2
# 19        1749  145  110    7       362    0
# ...

# %% [markdown]
# ## What are the largest / smallest x and y values on the file?

# %%
pc.x.max()
# Out:
# 637

# %%
pc.x.min()
# Out:
# 3

# %% [markdown]
# ## How many times an object is located in pixel x=121 y=251 ?

# %%
len(pc[(pc.x==121)&(pc.y==251)])
# Out:
# 1

# %% [markdown]
# ## Add more tasks from the original document here...

# %%
pc.groupby(['x', 'y']).size().sort_values()
# Out:
# x    y
# 384  320       1
# 537  56        1
#      36        1
#      30        1
# 102  84        1
# 537  29        1
#      25        1
# 102  54        1
# 537  67        1
# 102  4         1
# 101  336       1
#      324       1
#      281       1
#      279       1
# 537  11        1
#      10        1
#      9         1
# 101  340       1
#      275       1
# 537  75        1
#      94        1
# 102  157       1
# 403  290       1
#      297       1
#      328       1
# 595  166       1
# 403  354       1
#      355       1
# 537  84        1
# 102  140       1
#             ...
# 15   236     747
# 217  130     755
# 14   232     774
#      238     776
# 46   252     786
# 15   237     787
# 236  165     795
# 301  5       800
# 14   233     806
# 431  103     822
# 273  13      830
# 471  50      837
# 25   267     840
# 16   237     849
# 468  49      850
# 14   231     867
# 13   237     893
# 45   249     912
# 15   240     923
# 31   76      948
# 25   266     967
# ...

# %% [markdown]
# # distinct objects

# %%
len(pc.obj.unique())
# Out:
# 644

# %%
max=pc.seq.max()
max
# Out:
# 1977

# %%
pc[pc.seq==max].obj.unique()
# Out:
# array([16], dtype=uint64)

# %%
len(pc[pc.seq>=20].obj.unique())
# Out:
# 529

# %%
pc.groupby(['filename','obj']).seq.max().mean()
# Out:
# 82.90023984714826

# %%
fn="14-16\20170817012709_100.h264.txt"
obj=3
o=pc[(pc.filename==fn) & (pc.obj==obj)]
o.head()
# plot(o.x,o.y)
# Out:
# Empty DataFrame
# Columns: [frame, x, y, obj, size, seq, filename, start, path_time, delta_time]
# Index: []
